# %% [markdown]
# # 1. Write a python program to find a target values in a list using linear search with following steps.
#
# a. Initialize the list to store the input elements.
# b. Initialize found=False
# c. Enter the item to be searched(match_item)
# d. For Each element in the list
#                         if match_item=value
#                                return match_item's position
# e. If match_item is not in the list , display an error message that the item is not found in the list

# %%
input_list = [74, 21, 43, 8, 97]
found = False


match_item = int(input("Enter the item to be searched: "))

for index, value in enumerate(input_list):
    if value == match_item:
        found = True
        position = index   
        break


if found:
    print(f"{match_item} found at position {position}")
else:
    print(f"{match_item} is not found in the list.")
# Out:
# Enter the item to be searched: 8
# 8 found at position 3

# %% [markdown]
# # 2. Write Python Program to implement Binary Search to find the target values in the list.
# a. Create a separate function to do binary search
# b. Get the number of inputs from the user.
# c. Store the inputs individually in a list.
# d. In Binary Search function at first sort the list in the order to start the search from middle of the list.
# e. Compare the middle element to right and left elements to search  target element.
# f. If greater, move to right of list or else move to another side of the list.
# g. Print the result along with the position of element.

# %%
def binary_search(lst, target):
    left, right = 0, len(lst) - 1

    while left <= right:
        mid = left + (right - left) // 2  

        if lst[mid] == target:
            return mid 
        elif lst[mid] < target:
            left = mid + 1  
        else:
            right = mid - 1 
            
    return -1  


num_inputs = int(input("Enter the number of inputs: "))
input_list = []

for i in range(num_inputs):
    item = int(input(f"Enter input {i + 1}: "))
    input_list.append(item)

input_list.sort()


target = int(input("Enter the target value to search: "))
result = binary_search(input_list, target)

if result != -1:
    print(f"{target} found at position {result + 1}")
else:
    print(f"{target} is not found in the list.")
# Out:
# Enter the number of inputs: 7
# Enter input 1: 44
# Enter input 2: 15
# Enter input 3: 3
# Enter input 4: 67
# Enter input 5: 19
# Enter input 6: 15
# Enter input 7: 78
# Enter the target value to search: 15
# 15 found at position 2

# %% [markdown]
# # 3. Write a python Program for sorting a list of elements using Selection Sort Algorithm.
# a. Assume two lists : Sorted List -Initially empty and un-sorted list-Given Input list.
# b. In the first Iteration, find the smallest element in the unsorted list and place it in sorted list.
# c. In the second Iteration, find the smallest element in the unsorted list and place it in the correct position by comparing with the element in the sorted list .
# d. In the third Iteration, again find the smallest element in the unsorted list and place it in the correct position by comparing with the element in the sorted list.
# e. This process continues till the unsorted list becomes empty.
# f. Display the sorted list.

# %%
def selection_sort(input_list):
    sorted_list = []

    while input_list:

        min_element = min(input_list)
        sorted_list.append(min_element)
        input_list.remove(min_element)

    return sorted_list


input_list = []
num_elements = int(input("Enter the number of elements: "))

for i in range(num_elements):
    element = int(input(f"Enter element {i + 1}: "))
    input_list.append(element)


sorted_list = selection_sort(input_list)


print("Sorted list:")
for element in sorted_list:
    print(element, end=' ')
# Out:
# Enter the number of elements: 10
# Enter element 1: 78
# Enter element 2: 45
# Enter element 3: 95
# Enter element 4: 12
# Enter element 5: 35
# Enter element 6: 75
# Enter element 7: 11
# Enter element 8: 3
# Enter element 9: 26
# Enter element 10: 45
# Sorted list:
# 3 11 12 26 35 45 45 75 78 95

# %% [markdown]
# # 4.  Write a python Program for sorting a list of elements using Insertion Sort Algorithm.
# a. Assume two lists : Sorted List -Initially empty and un-sorted list-Given Input list.
# b. In the first Iteration, take the first element in the unsorted list and insert in the sorted list.
# c. In the second Iteration, take the second element in the given list amd compare with the element in the soretd sublist and place it in the correct position.
# d. In the third Iteration, take the third element in the given list and compare with the elements in the sorted sublist and place the elements in the correct position.
# e. This process continues until the last element is inserted in the sorted sub list.
# f. Display the sorted elements.

# %%
def insertion_sort(input_list):
    for i in range(1, len(input_list)):
        current_element = input_list[i]
        j = i - 1

        while j >= 0 and current_element < input_list[j]:
            input_list[j + 1] = input_list[j]
            j -= 1
        
        input_list[j + 1] = current_element


input_list = []
num_elements = int(input("Enter the number of elements: "))

for i in range(num_elements):
    element = int(input(f"Enter element {i + 1}: "))
    input_list.append(element)

insertion_sort(input_list)

print("Sorted list:")
for element in input_list:
    print(element, end=' ')
# Out:
# Enter the number of elements: 8
# Enter element 1: 42
# Enter element 2: 12
# Enter element 3: 62
# Enter element 4: 9
# Enter element 5: 77
# Enter element 6: 54
# Enter element 7: 99
# Enter element 8: 17
# Sorted list:
# 9 12 17 42 54 62 77 99

# %% [markdown]
# # 5. Write a python Program that performs merge sort on a list of numbers.
# a. Divide : If the given array has zero or one element, return
#                                     1. otherwise
#                                     ii. Divide the input list into two halves each containing half of the elements. i.e left half and right half.
# b. Conquer : Recursively sort the two lists (left half and right half).
#                         a. call the merge sort on left half.
#                         b. call the merge sort on right half.
# c. Combine : combine the elements back in the input list by merging the two sorted listsinto sorted sequence.

# %%
def merge_sort(lst):
    if len(lst) <= 1:
        return lst


    middle = len(lst) // 2
    left_half = lst[:middle]
    right_half = lst[middle:]

    left_half = merge_sort(left_half)
    right_half = merge_sort(right_half)

    sorted_lst = merge(left_half, right_half)

    return sorted_lst

def merge(left, right):
    result = []
    left_index, right_index = 0, 0

    while left_index < len(left) and right_index < len(right):
        if left[left_index] < right[right_index]:
            result.append(left[left_index])
            left_index += 1
        else:
            result.append(right[right_index])
            right_index += 1


    result.extend(left[left_index:])
    result.extend(right[right_index:])

    return result


input_list = []
num_elements = int(input("Enter the number of elements: "))

for i in range(num_elements):
    element = int(input(f"Enter element {i + 1}: "))
    input_list.append(element)

sorted_list = merge_sort(input_list)


print("Sorted list:")
for element in sorted_list:
    print(element, end=' ')
# Out:
# Enter the number of elements: 11
# Enter element 1: 54
# Enter element 2: 11
# Enter element 3: 18
# Enter element 4: 7
# Enter element 5: 98
# Enter element 6: 45
# Enter element 7: 63
# Enter element 8: 222
# Enter element 9: 81
# Enter element 10: 13
# Enter element 11: 78
# Sorted list:
# 7 11 13 18 45 54 63 78 81 98 222

# %% [markdown]
# # 6. Write a python script to perform the following operations on a singly linked list
#
# a. create a list.
# b. Find the smallest element from the list.
# c. Insert an element if it is not a duplicate element.
# d. Display the elements in reverse order.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node

    def find_smallest(self):
        if not self.head:
            return None
        smallest = self.head.data
        current = self.head.next
        while current:
            if current.data < smallest:
                smallest = current.data
            current = current.next
        return smallest

    def insert_if_not_duplicate(self, data):
        if not self.head:
            self.head = Node(data)
            return True

        current = self.head
        if current.data == data:
            return False

        while current.next:
            if current.next.data == data:
                return False
            current = current.next

        current.next = Node(data)
        return True

    def display_reverse(self):
        stack = []
        current = self.head
        while current:
            stack.append(current.data)
            current = current.next

        while stack:
            print(stack.pop(), end=' ')
        print()



linked_list = SinglyLinkedList()

num_elements = [11,54,78,91,14,74,5]

for i in num_elements:
    linked_list.append(i)


smallest = linked_list.find_smallest()
print(f"Smallest element in the list: {smallest}")


inserted = linked_list.insert_if_not_duplicate(5)
if inserted:
    print(" 5 is Inserted into the list.")
else:
    print("5 is already in the list and not inserted.")


print("Elements in reverse order:")
linked_list.display_reverse()
# Out:
# Smallest element in the list: 5
# 5 is already in the list and not inserted.
# Elements in reverse order:
# 5 74 14 91 78 54 11

# %% [markdown]
# # 7. Write a Python Program to implement the various operations for stack ADT
#      i) push   ii) pop iii) display

# %%
class Stack:
    def __init__(self):
        self.items = []

    def push(self, item):
        self.items.append(item)

    def pop(self):
        if not self.is_empty():
            return self.items.pop()
        else:
            return "Stack is empty"

    def is_empty(self):
        return len(self.items) == 0

    def display(self):
        if not self.is_empty():
            for item in reversed(self.items):
                print(item)
        else:
            print("Stack is empty")

# Create a stack
stack = Stack()

while True:
    print("\nStack Operations:")
    print("1. Push")
    print("2. Pop")
    print("3. Display")
    print("4. Quit")

    choice = input("Enter your choice (1/2/3/4): ")

    if choice == '1':
        item = input("Enter an item to push: ")
        stack.push(item)
        print(f"{item} pushed onto the stack.")
    elif choice == '2':
        popped_item = stack.pop()
        print(f"Popped item: {popped_item}")
    elif choice == '3':
        print("Stack contents:")
        stack.display()
    elif choice == '4':
        break
    else:
        print("Invalid choice. Please try again.")
# Out:
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter an item to push: 74
# 74 pushed onto the stack.
#
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter an item to push: 54
# 54 pushed onto the stack.
#
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 189
# Invalid choice. Please try again.
#
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter an item to push: 64
# 64 pushed onto the stack.
#
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter an item to push: 1
# 1 pushed onto the stack.
#
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 3
# Stack contents:
# 1
# 64
# 54
# 74
#
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 2
# Popped item: 1
#
# ...

# %% [markdown]
# # 8. Write a python Program to implement the various Operations for Queue ADT.
#        i)Insert  ii)Delete iii)Display

# %%
class Queue:
    def __init__(self):
        self.items = []

    def enqueue(self, item):
        self.items.append(item)

    def dequeue(self):
        if not self.is_empty():
            return self.items.pop(0)
        else:
            return "Queue is empty"

    def is_empty(self):
        return len(self.items) == 0

    def display(self):
        if not self.is_empty():
            for item in self.items:
                print(item)
        else:
            print("Queue is empty")

# Create a queue
queue = Queue()

while True:
    print("\nQueue Operations:")
    print("1. Enqueue")
    print("2. Dequeue")
    print("3. Display")
    print("4. Quit")

    choice = input("Enter your choice (1/2/3/4): ")

    if choice == '1':
        item = input("Enter an item to insert (enqueue): ")
        queue.enqueue(item)
        print(f"{item} inserted into the queue.")
    elif choice == '2':
        deleted_item = queue.dequeue()
        print(f"Deleted item: {deleted_item}")
    elif choice == '3':
        print("Queue contents:")
        queue.display()
    elif choice == '4':
        break
    else:
        print("Invalid choice. Please try again.")
# Out:
# Queue Operations:
# 1. Enqueue
# 2. Dequeue
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 3
# Queue contents:
# Queue is empty
#
# Queue Operations:
# 1. Enqueue
# 2. Dequeue
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter an item to insert (enqueue): 45
# 45 inserted into the queue.
#
# Queue Operations:
# 1. Enqueue
# 2. Dequeue
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter an item to insert (enqueue): 12
# 12 inserted into the queue.
#
# Queue Operations:
# 1. Enqueue
# 2. Dequeue
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter an item to insert (enqueue): 75
# 75 inserted into the queue.
#
# Queue Operations:
# 1. Enqueue
# 2. Dequeue
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter an item to insert (enqueue): 8
# 8 inserted into the queue.
#
# Queue Operations:
# 1. Enqueue
# 2. Dequeue
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 3
# Queue contents:
# 45
# 12
# 75
# 8
#
# Queue Operations:
# ...

# %% [markdown]
# # 9. Write a Program in Python to convert the following infix expression to postfix form using push and pop operations of stack
#
#     a. A/B^C+D*E-F*G
#     b. (B^2-4*A*C)^(1/2)(100)

# %%
def is_operator(char):
    return char in '+-*/^'

def precedence(operator):
    if operator in ('+', '-'):
        return 1
    elif operator in ('*', '/'):
        return 2
    elif operator == '^':
        return 3
    return 0

def infix_to_postfix(expression):
    stack = []
    postfix = []
    
    for char in expression:
        if char.isalnum():
            postfix.append(char)
        elif char == '(':
            stack.append(char)
        elif char == ')':
            while stack and stack[-1] != '(':
                postfix.append(stack.pop())
            stack.pop()  
        elif is_operator(char):
            while stack and stack[-1] != '(' and precedence(char) <= precedence(stack[-1]):
                postfix.append(stack.pop())
            stack.append(char)
    
    while stack:
        postfix.append(stack.pop())
    
    return ''.join(postfix)



infix_expression1 = "A/B^C+D*E-F*G"
infix_expression2 = "(B^2-4*A*C)^(1/2)(100)"

postfix_expression1 = infix_to_postfix(infix_expression1)
postfix_expression2 = infix_to_postfix(infix_expression2)

print("Infix Expression 1:", infix_expression1)
print("Postfix Expression 1:", postfix_expression1)

print("\nInfix Expression 2:", infix_expression2)
print("Postfix Expression 2:", postfix_expression2)
# Out:
# Infix Expression 1: A/B^C+D*E-F*G
# Postfix Expression 1: ABC^/DE*+FG*-
#
# Infix Expression 2: (B^2-4*A*C)^(1/2)(100)
# Postfix Expression 2: B2^4A*C*-12/100^
