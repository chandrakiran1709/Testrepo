# %% [markdown]
# # Day 1 - Predicting House Prices

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the data set

data=pd.read_csv('RealEstateData.csv')
data
# Out:
#      Crime.Rate.in.the.Area  Ratio.of.Commercial...Residential.Properties  \
# 0                   0.00632                                          2.31
# 1                   0.02731                                          7.07
# 2                   0.02729                                          7.07
# 3                   0.03237                                          2.18
# 4                   0.06905                                          2.18
# ..                      ...                                           ...
# 495                 0.06263                                         11.93
# 496                 0.04527                                         11.93
# 497                 0.06076                                         11.93
# 498                 0.10959                                         11.93
# 499                 0.04741                                         11.93
#
#      Number.of.Rooms  Age.of.Property  Distance...Nearest.Emp.hub  \
# ...

# %%
data.head()
# Out:
#    Crime.Rate.in.the.Area  Ratio.of.Commercial...Residential.Properties  \
# 0                 0.00632                                          2.31
# 1                 0.02731                                          7.07
# 2                 0.02729                                          7.07
# 3                 0.03237                                          2.18
# 4                 0.06905                                          2.18
#
#    Number.of.Rooms  Age.of.Property  Distance...Nearest.Emp.hub  \
# 0              4.0             65.0                      4.0900
# 1              4.0             78.0                      4.9671
# 2              5.0             61.0                      4.9671
# 3              4.0             45.0                      6.0622
# 4              5.0             54.0                      6.0622
#
#    Ratio.of.Lower.Income.people.in.area  Sale.Price.of.House
# 0                                  4.98            24.000000
# ...

# %%
data.tail()
# Out:
#      Crime.Rate.in.the.Area  Ratio.of.Commercial...Residential.Properties  \
# 495                 0.06263                                         11.93
# 496                 0.04527                                         11.93
# 497                 0.06076                                         11.93
# 498                 0.10959                                         11.93
# 499                 0.04741                                         11.93
#
#      Number.of.Rooms  Age.of.Property  Distance...Nearest.Emp.hub  \
# 495              4.0             69.0                      2.4786
# 496              4.0             76.0                      2.2875
# 497              4.0             91.0                      2.1675
# 498              4.0             89.0                      2.3889
# 499              4.0             80.0                      2.5050
#
#      Ratio.of.Lower.Income.people.in.area  Sale.Price.of.House
# ...

# %%
data.isna().sum()
# Out:
# Crime.Rate.in.the.Area                          7
# Ratio.of.Commercial...Residential.Properties    4
# Number.of.Rooms                                 4
# Age.of.Property                                 3
# Distance...Nearest.Emp.hub                      4
# Ratio.of.Lower.Income.people.in.area            6
# Sale.Price.of.House                             0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# Crime.Rate.in.the.Area                          0
# Ratio.of.Commercial...Residential.Properties    0
# Number.of.Rooms                                 0
# Age.of.Property                                 0
# Distance...Nearest.Emp.hub                      0
# Ratio.of.Lower.Income.people.in.area            0
# Sale.Price.of.House                             0
# dtype: int64

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Crime.Rate.in.the.Area'}>,
#         <Axes: title={'center': 'Ratio.of.Commercial...Residential.Properties'}>,
#         <Axes: title={'center': 'Number.of.Rooms'}>],
#        [<Axes: title={'center': 'Age.of.Property'}>,
#         <Axes: title={'center': 'Distance...Nearest.Emp.hub'}>,
#         <Axes: title={'center': 'Ratio.of.Lower.Income.people.in.area'}>],
#        [<Axes: title={'center': 'Sale.Price.of.House'}>, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
data.describe()
# Out:
#        Crime.Rate.in.the.Area  Ratio.of.Commercial...Residential.Properties  \
# count              473.000000                                    473.000000
# mean                 3.618486                                     11.171755
# std                  8.687044                                      6.901527
# min                  0.006320                                      0.460000
# 25%                  0.081990                                      5.190000
# 50%                  0.253870                                      9.690000
# 75%                  3.678220                                     18.100000
# max                 88.976196                                     27.740000
#
#        Number.of.Rooms  Age.of.Property  Distance...Nearest.Emp.hub  \
# count       473.000000       473.000000                  473.000000
# mean          3.778013        68.167019                    3.783121
# std           0.786123        28.241761                    2.115812
# ...

# %%
x=data.iloc[:,:1]
x.head(1)
# Out:
#    Crime.Rate.in.the.Area
# 0                 0.00632

# %%
y=data.iloc[:,-1:]
y.head(1)
# Out:
#    Sale.Price.of.House
# 0                 24.0

# %%
type(x), type(y)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.frame.DataFrame)

# %%
a=data.iloc[:,:1].values
b=data.iloc[:,-1:].values
a
# Out:
# array([[6.32000000e-03],
#        [2.73100010e-02],
#        [2.72900000e-02],
#        [3.23700010e-02],
#        [6.90499990e-02],
#        [2.98500010e-02],
#        [8.82899980e-02],
#        [1.44549996e-01],
#        [1.70039997e-01],
#        [2.24889994e-01],
#        [1.17470004e-01],
#        [9.37800030e-02],
#        [6.29760027e-01],
#        [6.37960017e-01],
#        [6.27390027e-01],
#        [7.84200013e-01],
#        [8.02709997e-01],
#        [7.25799978e-01],
#        [1.25179005e+00],
#        [8.52039993e-01],
#        [1.23247004e+00],
#        [9.88430023e-01],
#        [7.50259995e-01],
#        [8.40539992e-01],
#        [6.71909988e-01],
#        [9.55770016e-01],
#        [7.72989988e-01],
#        [1.00244999e+00],
#        [1.13081002e+00],
#        [1.35472000e+00],
#        [1.38799000e+00],
#        [1.15172005e+00],
#        [1.61282003e+00],
#        [6.41700030e-02],
#        [9.74399970e-02],
#        [8.01400020e-02],
#        [1.75050005e-01],
# ...

# %%
b
# Out:
# array([[24.        ],
#        [21.60000038],
#        [34.70000076],
#        [33.40000153],
#        [36.20000076],
#        [28.70000076],
#        [22.89999962],
#        [27.10000038],
#        [18.89999962],
#        [15.        ],
#        [18.89999962],
#        [21.70000076],
#        [20.39999962],
#        [18.20000076],
#        [19.89999962],
#        [17.5       ],
#        [20.20000076],
#        [18.20000076],
#        [13.60000038],
#        [19.60000038],
#        [15.19999981],
#        [14.5       ],
#        [15.60000038],
#        [13.89999962],
#        [16.60000038],
#        [14.80000019],
#        [18.39999962],
#        [21.        ],
#        [12.69999981],
#        [14.5       ],
#        [13.19999981],
#        [13.10000038],
#        [13.5       ],
#        [18.89999962],
#        [20.        ],
#        [21.        ],
#        [24.70000076],
#        [30.79999924],
#        [34.90000153],
#        [26.60000038],
#        [25.29999924],
# ...

# %%
data.corr()
# Out:
#                                               Crime.Rate.in.the.Area  \
# Crime.Rate.in.the.Area                                      1.000000
# Ratio.of.Commercial...Residential.Properties                0.398431
# Number.of.Rooms                                            -0.211114
# Age.of.Property                                             0.347853
# Distance...Nearest.Emp.hub                                 -0.373717
# Ratio.of.Lower.Income.people.in.area                        0.446699
# Sale.Price.of.House                                        -0.382950
#
#                                               Ratio.of.Commercial...Residential.Properties  \
# Crime.Rate.in.the.Area                                                            0.398431
# Ratio.of.Commercial...Residential.Properties                                      1.000000
# Number.of.Rooms                                                                  -0.376691
# ...

# %%
plt.scatter(x,y)
plt.title("Real estate")
plt.xlabel("Crime Rate in the Area")
plt.ylabel("sale price of the House")
plt.show()

# %%
import sklearn
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=20)

# %%
data.shape
# Out:
# (473, 7)

# %%
xtrain.shape
# Out:
# (378, 1)

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
print("Training Started.....\n")
print()
lin_reg.fit(xtrain,ytrain)
print()
print()
print("Training completed....")
print()
print("Testing invoked")
ypred=lin_reg.predict(xtest)
print("predicted Total Payment\n",ypred)
print('\n Testing is also completed....\n')
# Out:
# Training Started.....
#
#
#
#
# Training completed....
#
# Testing invoked
# predicted Total Payment
#  [[24.08702021]
#  [18.07483513]
#  [24.19254319]
#  [24.29968012]
#  [24.05166613]
#  [24.33048213]
#  [24.31617789]
#  [20.4299718 ]
#  [24.28162473]
#  [20.86441995]
#  [24.30350773]
#  [22.29508179]
#  [24.25861881]
#  [24.32100769]
#  [-2.99317317]
#  [24.22722916]
#  [24.28395511]
#  [24.33855192]
#  [23.35789429]
#  [23.77024202]
#  [24.33355308]
#  [24.32052471]
#  [24.32687186]
#  [20.04857117]
#  [24.2534791 ]
#  [23.79853656]
#  [24.33280446]
#  [21.31469775]
#  [21.12695164]
#  [21.99972373]
#  [24.09127445]
#  [24.29650855]
#  [24.31912809]
#  [24.32906137]
#  [24.31858071]
#  [22.56389613]
#  [24.25533455]
#  [21.77066671]
#  [24.31153324]
#  [24.31003198]
#  [16.00587167]
#  [24.32439257]
#  [24.31083694]
#  [22.03709416]
#  [24.32633253]
#  [24.32874341]
#  [24.25171622]
#  [24.31552587]
#  [23.88024057]
#  [24.27633208]
#  [22.15382225]
#  [24.28923569]
# ...

# %%
ytest
# Out:
#      Sale.Price.of.House
# 14             18.200001
# 463            19.100000
# 207            19.299999
# 498            22.000000
# 19             18.200001
# ..                   ...
# 443            12.600000
# 365            50.000000
# 75             20.799999
# 425             9.500000
# 454            20.000000
#
# [95 rows x 1 columns]

# %%
diff=ytest-ypred
diff
# Out:
#      Sale.Price.of.House
# 14             -5.887019
# 463             1.025165
# 207            -4.892544
# 498            -2.299680
# 19             -5.851665
# ..                   ...
# 443            -7.749205
# 365            27.938282
# 75             -3.508745
# 425           -11.085045
# 454            -1.606434
#
# [95 rows x 1 columns]

# %%
#visualise training data set

plt.scatter(xtrain,ytrain)
plt.plot(xtrain,lin_reg.predict(xtrain),color="red")
plt.title("real estate")
plt.xlabel("Crime Rate in the Area")
plt.ylabel("sale price of the House")
plt.show()

# %%
#visualise the test dataset
plt.scatter(xtrain,ytrain)
plt.plot(xtest,lin_reg.predict(xtest),color="red")
plt.title("real estate")
plt.xlabel("Crime Rate in the Area")
plt.ylabel("sale price of the House")
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score
print('Mean Squared Error: \t', mean_squared_error(ytest, ypred))
print()
print('RMSE: \t', np.sqrt(mean_squared_error(ytest, ypred)))
print()
print('Variance Score:\t', explained_variance_score (ytest,ypred))
print()
print('R-Square: \t', r2_score (ytest, ypred))
# Out:
# Mean Squared Error: 	 63.60005239723189
#
# RMSE: 	 7.974964100059128
#
# Variance Score:	 0.19022070005486047
#
# R-Square: 	 0.1620366185165768

# %%
#multiple linear Regression

mx=data.iloc[:,:4]
mx
# Out:
#      Crime.Rate.in.the.Area  Ratio.of.Commercial...Residential.Properties  \
# 0                   0.00632                                          2.31
# 1                   0.02731                                          7.07
# 2                   0.02729                                          7.07
# 3                   0.03237                                          2.18
# 4                   0.06905                                          2.18
# ..                      ...                                           ...
# 495                 0.06263                                         11.93
# 496                 0.04527                                         11.93
# 497                 0.06076                                         11.93
# 498                 0.10959                                         11.93
# 499                 0.04741                                         11.93
#
#      Number.of.Rooms  Age.of.Property
# 0                4.0             65.0
# ...

# %%
my=data.iloc[:,-1:]
my
# Out:
#      Sale.Price.of.House
# 0              24.000000
# 1              21.600000
# 2              34.700001
# 3              33.400002
# 4              36.200001
# ..                   ...
# 495            22.400000
# 496            20.600000
# 497            23.900000
# 498            22.000000
# 499            11.900000
#
# [473 rows x 1 columns]

# %%
import sklearn
from sklearn.model_selection import train_test_split
mxtrain,mxtest,mytrain,mytest=train_test_split(mx,my,test_size=0.2,random_state=20)

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
print("Training Started.....\n")
print()
lin_reg.fit(mxtrain,mytrain)
print()
print()
print("Training completed....")
print()
print("Testing invoked")
mypred=lin_reg.predict(mxtest)
print("predicted Total Payment\n",mypred)
print('\n Testing is also completed....\n')
# Out:
# Training Started.....
#
#
#
#
# Training completed....
#
# Testing invoked
# predicted Total Payment
#  [[25.0507309 ]
#  [14.32451902]
#  [18.52197201]
#  [24.12387261]
#  [19.57303794]
#  [27.20818723]
#  [32.91149986]
#  [20.59790571]
#  [27.42888594]
#  [20.94999765]
#  [26.16442646]
#  [21.66461569]
#  [24.94863072]
#  [32.10206083]
#  [ 3.39043979]
#  [19.20897673]
#  [25.19088729]
#  [33.61605858]
#  [21.71348029]
#  [21.76733932]
#  [26.9923906 ]
#  [27.23684511]
#  [24.44620168]
#  [20.50135501]
#  [24.91241563]
#  [24.45221198]
#  [31.97217935]
#  [20.99327641]
#  [14.95354257]
#  [22.29964481]
#  [19.9659555 ]
#  [25.2717332 ]
#  [27.20550493]
#  [27.4283821 ]
#  [24.70820959]
#  [21.70719293]
#  [20.15923498]
#  [21.24063013]
#  [21.01204697]
#  [19.55096021]
#  [ 6.60631349]
#  [27.7110212 ]
#  [33.65679835]
#  [27.835832  ]
#  [26.35326135]
#  [27.17858988]
#  [25.00284925]
#  [27.17957599]
#  [18.74299822]
#  [26.23939269]
#  [21.39554974]
#  [21.11949093]
# ...

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score
print('Mean Squared Error: \t', mean_squared_error(mytest, mypred))
print()
print('RMSE: \t', np.sqrt(mean_squared_error(mytest, mypred)))
print()
print('Variance Score:\t', explained_variance_score (mytest,mypred))


print()
print('R-Square: \t', r2_score (mytest, mypred))
# Out:
# Mean Squared Error: 	 34.595264593803556
#
# RMSE: 	 5.8817739325652045
#
# Variance Score:	 0.5779443442558616
#
# R-Square: 	 0.5441896066173821
