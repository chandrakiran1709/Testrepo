# %% [markdown]
# # 1. Write a python program to create  a base class "shape" with methods to calculate area and perimeter. then, create derived classes "Circle" and  "Rectangle" that inherit from the base class and calculate their respective areas and perimeters. Demonstrate their usage in a program.

# %%
import math

class Shape:
    def area(self):
        pass
    
    def perimeter(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius**2

    def perimeter(self):
        return 2 * math.pi * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

    def perimeter(self):
        return 2 * (self.length + self.width)

radius=int(input("Enter the radius of circle :"))
circle = Circle(radius)
print("Area of the circle = ", circle.area())
print("Perimeter of circle = ", circle.perimeter())

length=int(input("Enter length of rectangle : "))
width=int(input("Enter width of rectangle : "))
rectangle = Rectangle(length,width)
print("Area of the Rectangle =", rectangle.area())
print("Perimeter of the Rectangle =", rectangle.perimeter())
# Out:
# Enter the radius of circle :7
# Area of the circle =  153.93804002589985
# Perimeter of circle =  43.982297150257104
# Enter length of rectangle : 4
# Enter width of rectangle : 6
# Area of the Rectangle = 24
# Perimeter of the Rectangle = 20

# %% [markdown]
# #  2. write a python script to create a class "Person"  with private attributes for age and name. Implement a method called to calculate a person's eligibility for  voting based on the age. Ensure that age cannot be accessed directly but only through getter method

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def get_age(self):
        return self.age

    def is_eligible_for_voting(self):
        if self.age >= 18:
            return True
        else:
            return False

    def get_name(self):
        return self.name


name=input("enter name of person : ")
age=int(input("enter age of person : "))
person = Person(name, age)


if person.is_eligible_for_voting():
    print(f"{person.get_name()} is eligible to vote.")
else:
    print(f"{person.get_name()} is not eligible to vote.")
# Out:
# enter name of person : Ganesh
# enter age of person : 27
# Ganesh is eligible to vote.

# %% [markdown]
# # 3. Simple Banking System

# %%
class BankAccount:
    def __init__(self, account_number, account_holder_name, balance):
        self.account_number = account_number
        self.account_holder_name = account_holder_name
        self.balance = balance

    def get_account_number(self):
        return self.account_number

    def get_account_holder_name(self):
        return self.account_holder_name

    def get_balance(self):
        return self.balance

    def deposit(self, amount):
        if amount < 0:
            raise ValueError("Amount to deposit must be positive.")
        else:
            self.balance += amount

    def withdraw(self, amount):
        if amount < 0:
            raise ValueError("Amount to withdraw must be positive.")
        elif amount > self.balance:
            raise ValueError("Insufficient balance.")
        else:    
             self.balance -= amount


class SavingsAccount(BankAccount):
    def __init__(self, account_number, account_holder_name, balance, interest_rate):
        super().__init__(account_number, account_holder_name, balance)
        self.interest_rate = interest_rate

    def get_interest_rate(self):
        return self.interest_rate

    def calculate_interest(self):

        interest_amount = self.balance * (self.interest_rate / 100)
        self.balance += interest_amount
        return interest_amount


class CheckingAccount(BankAccount):
    def __init__(self, account_number, account_holder_name, balance, overdraft_limit):
        super().__init__(account_number, account_holder_name, balance)
        self.overdraft_limit = overdraft_limit

    def get_overdraft_limit(self):
        return self.overdraft_limit

    def withdraw(self, amount):

        if amount < 0:
            raise ValueError("Amount to withdraw must be non-negative.")
        if amount > (self.balance + self.overdraft_limit):
            raise ValueError("Withdrawal exceeds available balance and overdraft limit.")
        self.balance -= amount


        
        
  
while (1):
    print("select Acount Type: \n")
    print("1.Savings Account \n 2.Checking Account:")
    opt=int(input("select the option is "))
    if opt==1:

        savings_account = SavingsAccount("SAV12234", "Ganesh", 1000.0, 5.0)
        print(f"Savings Account Holder: {savings_account.get_account_holder_name()}")
        print(f"Account Number: {savings_account.get_account_number()}")
        print(f"Initial Balance: {savings_account.get_balance()}")


        savings_account.deposit(500.0)
        print(f"Updated Balance after deposit: {savings_account.get_balance()}")


        interest_amount = savings_account.calculate_interest()
        print(f"Interest Amount Added: {interest_amount}")
        print(f"Updated Balance after interest calculation: {savings_account.get_balance()}")
        break

    if opt==2:
        checking_account = CheckingAccount("CHK43773", "pavan", 800.0, 200.0)
        print(f"\nChecking Account Holder: {checking_account.get_account_holder_name()}")
        print(f"Account Number: {checking_account.get_account_number()}")
        print(f"Initial Balance: {checking_account.get_balance()}")
        print(f"Overdraft Limit: {checking_account.get_overdraft_limit()}")


        try:
            checking_account.withdraw(1000.0)
            print(f"Withdrawal Successful. Updated Balance: {checking_account.get_balance()}")
        except ValueError as e:
            print(f"Error: {str(e)}")
        break


        try:
            checking_account.withdraw(1000.0)
            print(f"Withdrawal Successful. Updated Balance: {checking_account.get_balance()}")
        except ValueError as e:
            print(f"Error: {str(e)}")
        break;
    else:
        print("Enter valid option")
# Out:
# select Acount Type:
#
# 1.Savings Account
#  2.Checking Account:
# select the option is 1
# Savings Account Holder: Ganesh
# Account Number: SAV12234
# Initial Balance: 1000.0
# Updated Balance after deposit: 1500.0
# Interest Amount Added: 75.0
# Updated Balance after interest calculation: 1575.0

# %% [markdown]
# # 4.Employee Management

# %%
class Employee:
    def __init__(self, name, employee_id, salary):
        self.name = name
        self.employee_id = employee_id
        self.salary = salary

    def get_name(self):
        return self.name

    def set_name(self, name):
        self.name = name

    def get_employee_id(self):
        return self.employee_id

    def set_employee_id(self, employee_id):
        self.employee_id = employee_id

    def get_salary(self):
        return self.salary

    def set_salary(self, salary):
        self.salary = salary


class FullTimeEmployee(Employee):
    def __init__(self, name, employee_id, annual_salary):
        super().__init__(name, employee_id, annual_salary)

    def calculate_salary(self):
        return self.get_salary() / 12  


class PartTimeEmployee(Employee):
    def __init__(self, name, employee_id, hours_worked, hourly_rate):
        super().__init__(name, employee_id, None)
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def get_hours_worked(self):
        return self.hours_worked

    def set_hours_worked(self, hours_worked):
        self.hours_worked = hours_worked

    def get_hourly_rate(self):
        return self.hourly_rate

    def set_hourly_rate(self, hourly_rate):
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate 

    
    
    
name=input("enter name of employee : ")
emp_id=int(input("enter employee Id : "))
while (1):
    print("1.Full-time\n2.Part-time")
    select=int(input("choose option"))
    if select==1:
        salary=int(input("enter Annual Salary : "))
        full_time_employee = FullTimeEmployee(name, emp_id, salary)
    elif select==2:
           hours=int(input("enter Hours worked : "))
           hour_rate=int(input("enter Hour Rate : "))
           part_time_employee = PartTimeEmployee(name, emp_id, hours,hour_rate)
    else:
        print("select valid option")
        break
    if select==1:
        print("\nEmployee Information  ")
        print(" Employee Type: Full-time")
        print("Name:", full_time_employee.get_name())
        print("Employee ID:", full_time_employee.get_employee_id())
        print("Annual Salary:", full_time_employee.get_salary())
        print("Monthly Salary:", full_time_employee.calculate_salary())
        break
    if select==2:
        print("\nEmployee Information  ")
        print("Employee Type: Part-Time")
        print("Name:", part_time_employee.get_name())
        print("Employee ID:", part_time_employee.get_employee_id())
        print("Hours Worked:", part_time_employee.get_hours_worked())
        print("Hourly Rate:", part_time_employee.get_hourly_rate())
        print("Monthly Salary:", part_time_employee.calculate_salary())
        break
# Out:
# enter name of employee : pavan
# enter employee Id : 855685
# 1.Full-time
# 2.Part-time
# choose option2
# enter Hours worked : 30
# enter Hour Rate : 15
#
# Employee Information
# Employee Type: Part-Time
# Name: pavan
# Employee ID: 855685
# Hours Worked: 30
# Hourly Rate: 15
# Monthly Salary: 450

# %% [markdown]
# # 5. Library Management System

# %%
import datetime

class Book:
    def __init__(self, title, author, isbn, genre):
        self.title = title
        self.author = author
        self.isbn = isbn
        self.genre = genre
        self.checked_out = False
        self.due_date = None

    def check_out(self):
        if not self.checked_out:
            self.checked_out = True
            self.due_date = datetime.date.today() + datetime.timedelta(days=14)
            return True
        return False

    def return_book(self):
        if self.checked_out:
            self.checked_out = False
            self.due_date = None
            return True
        return False

    def is_overdue(self):
        if self.checked_out and self.due_date < datetime.date.today():
            return True
        return False

    def __str__(self):
        return f"{self.title} by {self.author}"

class FictionBook(Book):
    def __init__(self, title, author, isbn, genre, is_series=False):
        super().__init__(title, author, isbn, genre)
        self.is_series = is_series

    def __str__(self):
        return super().__str__() + (", Series" if self.is_series else "")

class NonFictionBook(Book):
    def __init__(self, title, author, isbn, genre, topic):
        super().__init__(title, author, isbn, genre)
        self.topic = topic

    def __str__(self):
        return super().__str__() + f", Topic: {self.topic}"

class Patron:
    def __init__(self, name, email):
        self.name = name
        self.email = email
        self.checked_out_books = []

    def check_out_book(self, book):
        if book.check_out():
            self.checked_out_books.append(book)
            return True
        return False

    def return_book(self, book):
        if book in self.checked_out_books and book.return_book():
            self.checked_out_books.remove(book)
            return True
        return False

class Transaction:
    def __init__(self, book, patron, transaction_type):
        self.book = book
        self.patron = patron
        self.transaction_type = transaction_type
        self.date = datetime.date.today()

def notify_overdue_books(books,patron):
    today = datetime.date.today()
    overdue_books = [book for book in books if book.is_overdue()]
    for book in overdue_books:  
        print(f"Notification: {patron.name}, your book '{book.title}' is overdue!")


fiction_book = FictionBook("The Hobbit", "J.R.R. Tolkien", "978-0618968633", "Fantasy", True)
nonfiction_book = NonFictionBook("Sapiens", "Yuval Noah Harari", "978-0062316097", "History", "Human Evolution")


patron1 = Patron("Ganesh", "ganna3435@email.com")


patron1.check_out_book(fiction_book)
patron1.check_out_book(nonfiction_book)


fiction_book.checked_out = True
fiction_book.due_date = datetime.date.today() - datetime.timedelta(days=7)


notify_overdue_books([fiction_book],patron1)

patron1.return_book(fiction_book)
patron1.return_book(nonfiction_book)
# Out:
# Notification: Ganesh, your book 'The Hobbit' is overdue!
# True

# %% [markdown]
# # 6. Online Shopping Cart

# %%
class Product:
    def __init__(self, product_id, name, price, stock_quantity):
        self.product_id = product_id
        self.name = name
        self.price = price
        self.stock_quantity = stock_quantity

    def get_price(self):
        return self.price

    def is_available(self, quantity):
        return self.stock_quantity >= quantity

    def reduce_stock(self, quantity):
        if self.is_available(quantity):
            self.stock_quantity -= quantity
            return True
        return False

    def __str__(self):
        return f"{self.name} (${self.price})"


class ElectronicsProduct(Product):
    def __init__(self, product_id, name, price, stock_quantity, warranty_period):
        super().__init__(product_id, name, price, stock_quantity)
        self.warranty_period = warranty_period

    def __str__(self):
        return super().__str__() + f" (Warranty: {self.warranty_period} months)"


class ClothingProduct(Product):
    def __init__(self, product_id, name, price, stock_quantity, size):
        super().__init__(product_id, name, price, stock_quantity)
        self.size = size

    def __str__(self):
        return super().__str__() + f" (Size: {self.size})"


class ShoppingCart:
    def __init__(self):
        self.items = {}

    def add_item(self, product, quantity):
        if product.is_available(quantity):
            if product in self.items:
                self.items[product] += quantity
            else:
                self.items[product] = quantity
            product.reduce_stock(quantity)
            return True
        return False

    def calculate_total_cost(self):
        total_cost = 0
        for product, quantity in self.items.items():
            total_cost += product.get_price() * quantity
        return total_cost

    def __str__(self):
        return "Shopping Cart"


class Order:
    def __init__(self, customer_name, shipping_address, cart):
        self.customer_name = customer_name
        self.shipping_address = shipping_address
        self.cart = cart
        self.shipping_cost = 0

    def calculate_total_cost(self):
        cart_cost = self.cart.calculate_total_cost()
        return cart_cost + self.shipping_cost

    def add_shipping_cost(self, shipping_cost):
        self.shipping_cost = shipping_cost

    def checkout(self):
        for product, quantity in self.cart.items.items():
            product.stock_quantity += quantity
        self.cart.items = {}

    def __str__(self):
        return f"Order for {self.customer_name}"



laptop = ElectronicsProduct(1, "Laptop", 999, 10, 12)
shirt = ClothingProduct(2, "T-Shirt", 19, 50, "M")


cart = ShoppingCart()


cart.add_item(laptop, 2)
cart.add_item(shirt, 3)

cart_total = cart.calculate_total_cost()
print(f"Shopping Cart Total amount: {cart_total} Rupees")


order = Order("Ganesh", "3534, paul street, Hyderabad", cart)


order.add_shipping_cost(10.0)


order.checkout()


order_total = order.calculate_total_cost()
print(f"Order Total: {order_total} Rupees")
# Out:
# Shopping Cart Total amount: 2055 Rupees
# Order Total: 10.0 Rupees
